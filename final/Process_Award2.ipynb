# %%
from bs4 import BeautifulSoup 
from urllib.request import urlopen

import pandas as pd
import re
import nltk

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from wordcloud import WordCloud

from konlpy.corpus import kolaw
from konlpy.tag import Twitter
twitter = Twitter()
# Out:
# C:\python\anaconda352\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
def DataReadAndTop(path) :
    #파일 불러 오기    
    filepath = path
    f = open(filepath, 'r')
    good = f.read()
    f.close()
    #들어온 리스트묶음을 영화별로 파싱
    good_split=good.split("\n")
    result=[]
    j=0
    #영화별로 Top 100리스트 만들기. 
    for i in good_split :
        #댓글 단어로 파싱 
        gundo_nouns = twitter.nouns(i)
        #단어의 nltk 형태 변환
        gundo_nouns_nltk  = nltk.Text(gundo_nouns, name='군도')
        #진행상황 체크 
        type(gundo_nouns_nltk), len(gundo_nouns_nltk)
        #단어 뽑기 
        result.append(gundo_nouns_nltk.vocab().most_common(100))
        print(j)
        j+=1
    return result

def DataToDF(result) :
    award_list = ["오바야","신세계","변호인","사도","내부자들","오바야"]

    #data : 각 영화 Top100이 리스트 하나 하나에 들어가 있어야 합니다.
    #award_list : 수상작 영화목록이 있어야 합니다. 
    df = pd.DataFrame({"제목":result})
    df.index =  award_list
        
    return df 
    
def DataWrite(df) : 
    a = input("데이터를 파일로 만드시겠습니까? Y / N ")
    if a == "Y" :  
        b = input("파일 이름은? 짧게해주세요")
        df.to_csv(b)
        c = print(b,"이 이름으로 저장되었다. ")
    else : 
        c = print("Ok! good bye")
    return c

# %%
award_list = ["신세계","변호인","사도","내부자들"]
sanghun = SangHun()
result = sanghun.DataReadAndTop("winners_allreviews_1.csv")
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-d063aa85422a> in <module>()
#       1 award_list = ["신세계","변호인","사도","내부자들"]
#       2 sanghun = SangHun()
# ----> 3 result = sanghun.DataReadAndTop("winners_allreviews_1.csv")
#
# <ipython-input-35-397f787afca6> in DataReadAndTop(self, path)
#      15         for i in good_split :
#      16             #댓글 단어로 파싱
# ---> 17             gundo_nouns = twitter.nouns(i)
#      18             #단어의 nltk 형태 변환
#      19             gundo_nouns_nltk  = nltk.Text(gundo_nouns, name='군도')
#
# C:\python\anaconda352\lib\site-packages\konlpy\tag\_okt.py in nouns(self, phrase)
#      70         """Noun extractor."""
#      71
# ---> 72         tagged = self.pos(phrase)
#      73         return [s for s, t in tagged if t == 'Noun']
#      74
#
# C:\python\anaconda352\lib\site-packages\konlpy\tag\_okt.py in pos(self, phrase, norm, stem, join)
#      61                     phrase,
#      62                     jpype.java.lang.Boolean(norm),
# ---> 63                     jpype.java.lang.Boolean(stem)).toArray()
#      64         if join:
#      65             return [t for t in tokens]
#
# C:\python\anaconda352\lib\site-packages\jpype\_jclass.py in _getClassFor(javaClass)
#      76
#      77
# ---> 78 def _getClassFor(javaClass):
#      79     name = javaClass.getName()
#      80     if name in _CLASSES:
#
# KeyboardInterrupt:

# %%
result
# Out:
# [[],
#  [('신세계', 9392),
#   ('영화', 3618),
#   ('황정민', 1597),
#   ('연기', 1509),
#   ('최고', 1060),
#   ('배우', 836),
#   ('진짜', 818),
#   ('이정재', 778),
#   ('무간도', 778),
#   ('정말', 742),
#   ('느와르', 551),
#   ('스토리', 519),
#   ('점', 500),
#   ('말', 432),
#   ('한국', 397),
#   ('조폭', 393),
#   ('연기력', 359),
#   ('대박', 335),
#   ('번', 333),
#   ('보고', 331),
#   ('하나', 321),
#   ('생각', 313),
#   ('더', 305),
#   ('최민식', 301),
#   ('것', 294),
#   ('이', 293),
#   ('한국영', 279),
#   ('또', 258),
#   ('다시', 245),
#   ('정도', 240),
#   ('그냥', 223),
#   ('박성웅', 220),
#   ('굿', 218),
#   ('평점', 214),
#   ('의리', 205),
#   ('좀', 204),
#   ('그', 202),
#   ('볼', 194),
#   ('재미', 192),
#   ('내', 192),
#   ('최고다', 183),
#   ('수', 178),
#   ('사람', 177),
#   ('처음', 173),
#   ('명작', 170),
#   ('연출', 169),
#   ('왜', 169),
#   ('내용', 168),
#   ('장면', 166),
#   ('반전', 165),
#   ('거', 160),
#   ('캐릭터', 159),
#   ('몰입', 158),
#   ('역시', 156),
#   ('남자', 155),
#   ('브라더', 154),
#   ('만', 153),
#   ('마지막', 151),
#   ('중', 146),
#   ('뭐', 146),
#   ('몰입도', 146),
#   ('듯', 146),
#   ('으리', 145),
#   ('감독', 143),
#   ('때', 140),
#   ('완전', 137),
#   ('느낌', 135),
#   ('깡패', 134),
#   ('임', 134),
#   ('인생', 132),
#   ('시간', 129),
#   ('긴장감', 129),
#   ('안', 126),
#   ('작품', 124),
#   ('여운', 124),
#   ('꼭', 122),
#   ('정청', 122),
#   ('이건', 121),
#   ('모두', 117),
#   ('대부', 116),
#   ('한번', 115),
#   ('끝', 114),
#   ('결말', 111),
#   ('소름', 110),
#   ('이자성', 109),
#   ('기대', 106),
#   ('이영화', 105),
#   ('나', 104),
#   ('이상', 103),
#   ('대사', 102),
#   ('다른', 99),
#   ('경찰', 98),
#   ('걸', 97),
#   ('짱', 97),
#   ('드루', 96),
#   ('시나리오', 93),
#   ('개', 91),
#   ('범죄', 90),
#   ('감', 90),
#   ('매력', 89)],
#  [('영화', 4323),
#   ('최고', 806),
#   ('정말', 804),
#   ('송강호', 800),
#   ('감동', 786),
#   ('국민', 777),
#   ('연기', 694),
#   ('생각', 627),
#   ('이', 617),
#   ('점', 589),
#   ('사람', 559),
#   ('노무현', 553),
#   ('말', 508),
#   ('것', 495),
#   ('대통령', 495),
#   ('대한민국', 481),
#   ('꼭', 474),
#   ('다시', 441),
#   ('그', 413),
#   ('가슴', 403),
#   ('민주주의', 403),
#   ('지금', 398),
#   ('진짜', 363),
#   ('분', 338),
#   ('국가', 334),
#   ('배우', 329),
#   ('우리', 329),
#   ('보고', 325),
#   ('평점', 307),
#   ('더', 281),
#   ('수', 277),
#   ('정치', 254),
#   ('시대', 231),
#   ('눈물', 226),
#   ('한번', 209),
#   ('때', 197),
#   ('왜', 195),
#   ('내', 193),
#   ('역사', 192),
#   ('우리나라', 182),
#   ('현실', 181),
#   ('세상', 178),
#   ('권력', 175),
#   ('그냥', 174),
#   ('란', 168),
#   ('마음', 166),
#   ('모든', 163),
#   ('나라', 163),
#   ('볼', 162),
#   ('미화', 162),
#   ('존경', 161),
#   ('정의', 161),
#   ('이야기', 160),
#   ('일베충', 156),
#   ('또', 150),
#   ('위해', 149),
#   ('재미', 146),
#   ('번', 143),
#   ('바위', 142),
#   ('이영화', 141),
#   ('자체', 140),
#   ('이제', 138),
#   ('사회', 135),
#   ('걸', 132),
#   ('사실', 132),
#   ('연기력', 127),
#   ('라면', 126),
#   ('주권', 124),
#   ('사건', 121),
#   ('나', 120),
#   ('내용', 119),
#   ('역시', 115),
#   ('알', 114),
#   ('현재', 114),
#   ('스토리', 111),
#   ('무엇', 111),
#   ('하나', 110),
#   ('변호사', 110),
#   ('추천', 109),
#   ('정도', 109),
#   ('빨갱이', 108),
#   ('인생', 106),
#   ('실화', 106),
#   ('계란', 105),
#   ('진실', 103),
#   ('좀', 102),
#   ('과거', 101),
#   ('위', 100),
#   ('내내', 100),
#   ('일베', 100),
#   ('마지막', 99),
#   ('일', 99),
#   ('제', 97),
#   ('모두', 97),
#   ('처음', 96),
#   ('작품', 96),
#   ('때문', 95),
#   ('인물', 92),
#   ('당신', 92),
#   ('인간', 92)],
#  [('영화', 2835),
#   ('연기', 2126),
#   ('유아인', 1884),
#   ('송강호', 919),
#   ('배우', 908),
#   ('세자', 721),
#   ('정말', 694),
#   ('연기력', 594),
#   ('역사', 578),
#   ('생각', 577),
#   ('최고', 536),
#   ('영조', 486),
#   ('아버지', 465),
#   ('아들', 458),
#   ('것', 427),
#   ('진짜', 410),
#   ('감동', 372),
#   ('눈물', 336),
#   ('내용', 336),
#   ('마음', 336),
#   ('볼', 327),
#   ('더', 314),
#   ('왕', 289),
#   ('마지막', 282),
#   ('수', 280),
#   ('사람', 280),
#   ('좀', 279),
#   ('이야기', 272),
#   ('소지섭', 270),
#   ('그', 264),
#   ('가슴', 262),
#   ('말', 258),
#   ('스토리', 257),
#   ('보고', 239),
#   ('점', 235),
#   ('이', 233),
#   ('재미', 233),
#   ('문근영', 223),
#   ('다시', 222),
#   ('자식', 219),
#   ('몰입', 214),
#   ('부모', 207),
#   ('때', 205),
#   ('역시', 202),
#   ('사극', 196),
#   ('그냥', 189),
#   ('느낌', 185),
#   ('이해', 179),
#   ('감독', 179),
#   ('부분', 178),
#   ('기대', 175),
#   ('여운', 173),
#   ('조금', 172),
#   ('한번', 167),
#   ('정조', 166),
#   ('비극', 159),
#   ('연출', 155),
#   ('가족', 154),
#   ('듯', 152),
#   ('장면', 152),
#   ('알', 150),
#   ('분장', 147),
#   ('감정', 146),
#   ('작품', 145),
#   ('표현', 144),
#   ('시간', 141),
#   ('왜', 139),
#   ('내', 137),
#   ('또', 136),
#   ('굿', 136),
#   ('함', 131),
#   ('모두', 130),
#   ('별로', 129),
#   ('하나', 129),
#   ('의', 128),
#   ('이준익', 128),
#   ('끝', 126),
#   ('정도', 126),
#   ('꼭', 125),
#   ('나', 125),
#   ('사실', 124),
#   ('추천', 120),
#   ('만', 118),
#   ('관계', 118),
#   ('평점', 116),
#   ('사랑', 115),
#   ('처음', 115),
#   ('대박', 115),
#   ('내내', 114),
#   ('부자', 108),
#   ('갈등', 107),
#   ('몰입도', 103),
#   ('짱', 102),
#   ('아역', 102),
#   ('대해', 102),
#   ('계속', 102),
#   ('약간', 102),
#   ('때문', 100),
#   ('감', 100),
#   ('음악', 99)],
#  [('영화', 2684),
#   ('이병헌', 2134),
#   ('연기', 2016),
#   ('배우', 811),
#   ('최고', 720),
#   ('조승우', 669),
#   ('정말', 640),
#   ('진짜', 589),
#   ('현실', 513),
#   ('연기력', 426),
#   ('스토리', 388),
#   ('반전', 329),
#   ('역시', 328),
#   ('더', 300),
#   ('재미', 300),
#   ('생각', 285),
#   ('말', 276),
#   ('점', 266),
#   ('볼', 264),
#   ('이', 259),
#   ('내용', 250),
#   ('것', 242),
#   ('굿', 240),
#   ('좀', 231),
#   ('백윤식', 213),
#   ('모히또', 203),
#   ('보고', 198),
#   ('대한민국', 197),
#   ('시간', 194),
#   ('장면', 189),
#   ('몰디브', 184),
#   ('그냥', 180),
#   ('사람', 173),
#   ('완전', 168),
#   ('다시', 161),
#   ('또', 155),
#   ('대박', 154),
#   ('듯', 150),
#   ('수', 148),
#   ('평점', 147),
#   ('한잔', 146),
#   ('잼', 143),
#   ('사회', 141),
#   ('마지막', 140),
#   ('연기자', 140),
#   ('그', 135),
#   ('감독판', 133),
#   ('만', 133),
#   ('정도', 132),
#   ('한국영', 131),
#   ('한국', 129),
#   ('인정', 127),
#   ('최고다', 127),
#   ('정치', 126),
#   ('왜', 116),
#   ('번', 115),
#   ('짱', 112),
#   ('병헌', 111),
#   ('꼭', 109),
#   ('기대', 108),
#   ('감독', 107),
#   ('정의', 107),
#   ('리지', 107),
#   ('임', 103),
#   ('하나', 103),
#   ('결말', 103),
#   ('사투리', 101),
#   ('함', 100),
#   ('별로', 100),
#   ('느낌', 100),
#   ('한번', 97),
#   ('거', 97),
#   ('우리나라', 97),
#   ('조금', 94),
#   ('연출', 93),
#   ('간만', 93),
#   ('우리', 92),
#   ('개', 91),
#   ('뭐', 91),
#   ('꿀잼', 91),
#   ('나', 89),
#   ('추천', 89),
#   ('몰입', 87),
#   ('널', 87),
#   ('소름', 83),
#   ('때문', 81),
#   ('몰입도', 81),
#   ('때', 79),
#   ('작품', 79),
#   ('부분', 77),
#   ('아주', 77),
#   ('지금', 76),
#   ('시나리오', 76),
#   ('모두', 76),
#   ('전개', 75),
#   ('끝', 75),
#   ('내', 74),
#   ('요', 74),
#   ('베테', 73),
#   ('실제', 71)],
#  []]

# %%
df = DataToDF(result)

# %%
df = df[1:5]

# %%
def ShWordCloud(df) : 
    plt.
# Out:
# {('가슴', 403),
#  ('감동', 786),
#  ('걸', 132),
#  ('것', 495),
#  ('계란', 105),
#  ('과거', 101),
#  ('국가', 334),
#  ('국민', 777),
#  ('권력', 175),
#  ('그', 413),
#  ('그냥', 174),
#  ('꼭', 474),
#  ('나', 120),
#  ('나라', 163),
#  ('내', 193),
#  ('내내', 100),
#  ('내용', 119),
#  ('노무현', 553),
#  ('눈물', 226),
#  ('다시', 441),
#  ('당신', 92),
#  ('대통령', 495),
#  ('대한민국', 481),
#  ('더', 281),
#  ('때', 197),
#  ('때문', 95),
#  ('또', 150),
#  ('라면', 126),
#  ('란', 168),
#  ('마음', 166),
#  ('마지막', 99),
#  ('말', 508),
#  ('모두', 97),
#  ('모든', 163),
#  ('무엇', 111),
#  ('미화', 162),
#  ('민주주의', 403),
#  ('바위', 142),
#  ('배우', 329),
#  ('번', 143),
#  ('변호사', 110),
#  ('보고', 325),
#  ('볼', 162),
#  ('분', 338),
#  ('빨갱이', 108),
#  ('사건', 121),
#  ('사람', 559),
#  ('사실', 132),
#  ('사회', 135),
#  ('생각', 627),
#  ('세상', 178),
#  ('송강호', 800),
#  ('수', 277),
#  ('스토리', 111),
#  ('시대', 231),
#  ('실화', 106),
#  ('알', 114),
#  ('역사', 192),
#  ('역시', 115),
#  ('연기', 694),
#  ('연기력', 127),
#  ('영화', 4323),
#  ('왜', 195),
#  ('우리', 329),
#  ('우리나라', 182),
#  ('위', 100),
#  ('위해', 149),
#  ('이', 617),
#  ('이야기', 160),
#  ('이영화', 141),
#  ('이제', 138),
#  ('인간', 92),
#  ('인물', 92),
#  ('인생', 106),
#  ('일', 99),
#  ('일베', 100),
#  ('일베충', 156),
#  ('자체', 140),
#  ('작품', 96),
#  ('재미', 146),
#  ('점', 589),
#  ('정도', 109),
#  ('정말', 804),
#  ('정의', 161),
#  ('정치', 254),
#  ('제', 97),
#  ('존경', 161),
#  ('좀', 102),
#  ('주권', 124),
#  ('지금', 398),
#  ('진실', 103),
#  ('진짜', 363),
#  ('처음', 96),
#  ('최고', 806),
#  ('추천', 109),
#  ('평점', 307),
#  ('하나', 110),
#  ('한번', 209),
#  ('현실', 181),
#  ('현재', 114)}

# %%
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                      background_color='white',
                      relative_scaling =0.2).generate_from_frequencies(dict(df["제목"][1]))

# %%
plt.figure(figsize=(20,12))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
winners_allreviews_3

# %%
f = open("winners_allreviews_3.csv", 'r')
good = f.read()
f.close()

j=0
#영화별로 Top 100리스트 만들기. 
#댓글 단어로 파싱 
gundo_nouns = twitter.nouns(good)
#단어의 nltk 형태 변환
gundo_nouns_nltk  = nltk.Text(gundo_nouns, name='이상훈작품')
#진행상황 체크 
type(gundo_nouns_nltk), len(gundo_nouns_nltk)
#단어 뽑기 
result_total=gundo_nouns_nltk.vocab().most_common(200)

result_total
# Out:
# [('영화', 31246),
#  ('연기', 10258),
#  ('신세계', 9445),
#  ('정말', 5792),
#  ('배우', 5346),
#  ('최고', 4835),
#  ('감동', 4768),
#  ('진짜', 4320),
#  ('생각', 4239),
#  ('것', 3372),
#  ('점', 3339),
#  ('스토리', 3114),
#  ('이', 2987),
#  ('더', 2922),
#  ('꼭', 2893),
#  ('사람', 2656),
#  ('말', 2609),
#  ('송강호', 2465),
#  ('보고', 2434),
#  ('볼', 2337),
#  ('재미', 2330),
#  ('그', 2251),
#  ('내용', 2186),
#  ('이병헌', 2142),
#  ('나라', 2115),
#  ('수', 2094),
#  ('연기력', 2087),
#  ('역사', 2075),
#  ('좀', 1988),
#  ('그냥', 1972),
#  ('다시', 1929),
#  ('유아인', 1891),
#  ('평점', 1856),
#  ('눈물', 1800),
#  ('가슴', 1773),
#  ('앨리스', 1713),
#  ('정우성', 1637),
#  ('반전', 1622),
#  ('왜', 1621),
#  ('황정민', 1610),
#  ('감독', 1606),
#  ('장면', 1546),
#  ('마지막', 1528),
#  ('역시', 1523),
#  ('마음', 1495),
#  ('현실', 1395),
#  ('정도', 1383),
#  ('때', 1356),
#  ('한번', 1348),
#  ('우리', 1296),
#  ('시간', 1272),
#  ('내', 1267),
#  ('느낌', 1266),
#  ('하나', 1259),
#  ('또', 1256),
#  ('번', 1238),
#  ('연출', 1238),
#  ('국민', 1176),
#  ('이야기', 1174),
#  ('나', 1170),
#  ('처음', 1154),
#  ('듯', 1144),
#  ('작품', 1117),
#  ('한효주', 1110),
#  ('김민희', 1108),
#  ('대한민국', 1089),
#  ('굿', 1088),
#  ('한국', 1067),
#  ('추천', 1051),
#  ('대박', 1034),
#  ('모두', 1025),
#  ('부분', 1020),
#  ('지금', 1011),
#  ('기대', 1009),
#  ('만', 1000),
#  ('한국영', 990),
#  ('거', 982),
#  ('몰입', 978),
#  ('돈', 976),
#  ('끝', 951),
#  ('조금', 936),
#  ('알', 912),
#  ('완전', 906),
#  ('뭐', 897),
#  ('분', 891),
#  ('별로', 889),
#  ('보기', 850),
#  ('내내', 836),
#  ('나문희', 832),
#  ('함', 823),
#  ('박찬욱', 823),
#  ('광주', 821),
#  ('기억', 809),
#  ('긴장감', 809),
#  ('전개', 806),
#  ('때문', 805),
#  ('안', 804),
#  ('중간', 802),
#  ('무간도', 780),
#  ('이정재', 780),
#  ('임', 778),
#  ('사실', 773),
#  ('우리나라', 756),
#  ('인생', 755),
#  ('위안부', 750),
#  ('소재', 750),
#  ('이정현', 745),
#  ('저', 725),
#  ('세자', 721),
#  ('가족', 720),
#  ('자체', 715),
#  ('중', 695),
#  ('모든', 694),
#  ('여운', 690),
#  ('감', 682),
#  ('계속', 678),
#  ('이해', 678),
#  ('조승우', 673),
#  ('이상', 667),
#  ('몰입도', 665),
#  ('걸', 654),
#  ('이영화', 636),
#  ('개', 632),
#  ('요', 630),
#  ('결말', 628),
#  ('못', 624),
#  ('가장', 613),
#  ('짱', 612),
#  ('눈', 610),
#  ('표현', 604),
#  ('줄', 600),
#  ('사회', 594),
#  ('아주', 593),
#  ('세상', 591),
#  ('명작', 581),
#  ('사건', 581),
#  ('느와르', 574),
#  ('노무현', 564),
#  ('대해', 558),
#  ('이건', 556),
#  ('일', 552),
#  ('뭔가', 552),
#  ('다른', 549),
#  ('캐릭터', 547),
#  ('속', 546),
#  ('시대', 545),
#  ('아들', 540),
#  ('실화', 537),
#  ('대통령', 533),
#  ('대한', 529),
#  ('아버지', 522),
#  ('개인', 520),
#  ('라면', 517),
#  ('최고다', 516),
#  ('전', 516),
#  ('사랑', 514),
#  ('민주주의', 511),
#  ('설경구', 511),
#  ('이제', 506),
#  ('일본', 505),
#  ('게', 493),
#  ('난', 489),
#  ('액션', 486),
#  ('영조', 486),
#  ('감정', 484),
#  ('후반', 484),
#  ('잼', 481),
#  ('위해', 480),
#  ('대사', 479),
#  ('정치', 478),
#  ('진심', 474),
#  ('약간', 474),
#  ('집중', 473),
#  ('할머니', 472),
#  ('제', 468),
#  ('남자', 467),
#  ('영화로', 464),
#  ('모습', 457),
#  ('소름', 454),
#  ('도', 450),
#  ('구성', 444),
#  ('무엇', 443),
#  ('영화관', 440),
#  ('기분', 438),
#  ('조폭', 437),
#  ('의미', 436),
#  ('인상', 436),
#  ('간만', 431),
#  ('인간', 428),
#  ('올해', 427),
#  ('제대로', 426),
#  ('스릴', 426),
#  ('영화인', 424),
#  ('앞', 423),
#  ('놈', 421),
#  ('의', 418),
#  ('쓰레기', 416),
#  ('여자', 415),
#  ('웃음', 414),
#  ('기도', 403)]

# %%
df_total=pd.DataFrame({"결과":result_total})

# %%
df_total["결과"]
# Out:
# 0      (영화, 31246)
# 1      (연기, 10258)
# 2      (신세계, 9445)
# 3       (정말, 5792)
# 4       (배우, 5346)
# 5       (최고, 4835)
# 6       (감동, 4768)
# 7       (진짜, 4320)
# 8       (생각, 4239)
# 9        (것, 3372)
# 10       (점, 3339)
# 11     (스토리, 3114)
# 12       (이, 2987)
# 13       (더, 2922)
# 14       (꼭, 2893)
# 15      (사람, 2656)
# 16       (말, 2609)
# 17     (송강호, 2465)
# 18      (보고, 2434)
# 19       (볼, 2337)
# 20      (재미, 2330)
# 21       (그, 2251)
# 22      (내용, 2186)
# 23     (이병헌, 2142)
# 24      (나라, 2115)
# 25       (수, 2094)
# 26     (연기력, 2087)
# 27      (역사, 2075)
# 28       (좀, 1988)
# 29      (그냥, 1972)
#           ...
# 170      (진심, 474)
# 171      (약간, 474)
# 172      (집중, 473)
# 173     (할머니, 472)
# 174       (제, 468)
# 175      (남자, 467)
# 176     (영화로, 464)
# 177      (모습, 457)
# 178      (소름, 454)
# 179       (도, 450)
# 180      (구성, 444)
# 181      (무엇, 443)
# 182     (영화관, 440)
# 183      (기분, 438)
# 184      (조폭, 437)
# 185      (의미, 436)
# 186      (인상, 436)
# 187      (간만, 431)
# 188      (인간, 428)
# 189      (올해, 427)
# 190     (제대로, 426)
# 191      (스릴, 426)
# 192     (영화인, 424)
# 193       (앞, 423)
# 194       (놈, 421)
# 195       (의, 418)
# 196     (쓰레기, 416)
# 197      (여자, 415)
# 198      (웃음, 414)
# 199      (기도, 403)
# Name: 결과, Length: 200, dtype: object

# %%
dict(df_total["결과"].values)["이정재"]
print(dict(df_total["결과"].values)["천우희"]/sum(dict(df_total["결과"].values).values())*100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-81a424a011f9> in <module>()
#       1 dict(df_total["결과"].values)["이정재"]
# ----> 2 print(dict(df_total["결과"].values)["천우희"]/sum(dict(df_total["결과"].values).values())*100)
#
# KeyError: '천우희'

# %%
df_total["결과"]
# Out:
# 0      (영화, 31246)
# 1      (연기, 10258)
# 2      (신세계, 9445)
# 3       (정말, 5792)
# 4       (배우, 5346)
# 5       (최고, 4835)
# 6       (감동, 4768)
# 7       (진짜, 4320)
# 8       (생각, 4239)
# 9        (것, 3372)
# 10       (점, 3339)
# 11     (스토리, 3114)
# 12       (이, 2987)
# 13       (더, 2922)
# 14       (꼭, 2893)
# 15      (사람, 2656)
# 16       (말, 2609)
# 17     (송강호, 2465)
# 18      (보고, 2434)
# 19       (볼, 2337)
# 20      (재미, 2330)
# 21       (그, 2251)
# 22      (내용, 2186)
# 23     (이병헌, 2142)
# 24      (나라, 2115)
# 25       (수, 2094)
# 26     (연기력, 2087)
# 27      (역사, 2075)
# 28       (좀, 1988)
# 29      (그냥, 1972)
#           ...
# 170      (진심, 474)
# 171      (약간, 474)
# 172      (집중, 473)
# 173     (할머니, 472)
# 174       (제, 468)
# 175      (남자, 467)
# 176     (영화로, 464)
# 177      (모습, 457)
# 178      (소름, 454)
# 179       (도, 450)
# 180      (구성, 444)
# 181      (무엇, 443)
# 182     (영화관, 440)
# 183      (기분, 438)
# 184      (조폭, 437)
# 185      (의미, 436)
# 186      (인상, 436)
# 187      (간만, 431)
# 188      (인간, 428)
# 189      (올해, 427)
# 190     (제대로, 426)
# 191      (스릴, 426)
# 192     (영화인, 424)
# 193       (앞, 423)
# 194       (놈, 421)
# 195       (의, 418)
# 196     (쓰레기, 416)
# 197      (여자, 415)
# 198      (웃음, 414)
# 199      (기도, 403)
# Name: 결과, Length: 200, dtype: object

# %%
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                      background_color='white',
                      relative_scaling =0.2).generate_from_frequencies(dict(df_total["결과"].values))

# %%
plt.figure(figsize=(30,20))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
